# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Loading dataset to a pandas dataframe
df=pd.read_csv('creditcard.csv')

# %%
# 5 random rowss of dataset
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
# dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# checking the no. of missing values in each column
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# distribution of legit transcation and  fraudlent transc.
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
# So here we can see that legit transc are more than fraudlent one so whenever we give any test data it will predict it as. normal transc .
# This is unbalanced dataset and we cannot train our machine learning model in it
# 0    284315 (Normal Transc.)
# 1       492 (Fraud Transc.)

# %%
# Seprating the data for analysis
legit=df[df.Class==0]
fraud=df[df.Class==1]

# %%
fraud.shape
# Out:
# (492, 31)

# %%
# Satatical mearsure of the data
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# Compare the values for both transc
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
# Under Sampling
# Build sample dataset containg similar distribution of legit transc. and fraud transc.

# %%
legitSample=legit.sample(n=492)

# %%
legitSample
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 112470   72660.0  1.076399 -0.236834  1.326728  0.744335 -0.916717  0.384935
# 22618    32344.0  1.260574  0.109461  0.059664  0.096582 -0.390486 -1.317197
# 82232    59312.0 -0.985385  0.127735  2.343602  1.689115 -1.392629  1.232577
# 126920   78147.0  0.689604 -0.676754 -0.398769  0.577305 -0.269999 -0.634893
# 70909    54071.0  1.146286 -0.358282  0.688945  0.382457 -1.016927 -0.711002
# ...          ...       ...       ...       ...       ...       ...       ...
# 117170   74567.0 -0.585557  1.310272  1.198312  0.010049  0.042373 -1.002060
# 54941    46694.0  0.082187 -1.642039  0.358387  1.440360 -0.912515  0.663564
# 250151  154753.0 -0.756284 -0.500967  1.149397 -1.191394  0.773842  0.304727
# 85424    60765.0 -0.336502  0.912666  1.930708  2.904695  0.045819  0.907801
# 238425  149661.0 -3.841720  3.405097 -2.614096 -1.244508 -1.219199 -1.873810
#
# ...

# %%
# Concatenating two dataframe

# %%
newDF=pd.concat([legitSample,fraud],axis=0) # axis=0 (row wise)   and axis=1 (column wise)

# %%
newDF
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 112470   72660.0  1.076399 -0.236834  1.326728  0.744335 -0.916717  0.384935
# 22618    32344.0  1.260574  0.109461  0.059664  0.096582 -0.390486 -1.317197
# 82232    59312.0 -0.985385  0.127735  2.343602  1.689115 -1.392629  1.232577
# 126920   78147.0  0.689604 -0.676754 -0.398769  0.577305 -0.269999 -0.634893
# 70909    54071.0  1.146286 -0.358282  0.688945  0.382457 -1.016927 -0.711002
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
newDF['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
newDF.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      97017.565041  0.086461 -0.035076  0.027259  0.064887  0.058205
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.005131  0.058032  0.072837  0.007797  ...  0.011319  0.012192
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.004446 -0.004827 -0.011717 -0.020942  0.003325  0.009215 -0.012297
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       91.504512
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
# Splitting the data into features and targets

# %%
X=newDF.drop(columns='Class',axis=1)
y=newDF['Class']

# %%
X
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 112470   72660.0  1.076399 -0.236834  1.326728  0.744335 -0.916717  0.384935
# 22618    32344.0  1.260574  0.109461  0.059664  0.096582 -0.390486 -1.317197
# 82232    59312.0 -0.985385  0.127735  2.343602  1.689115 -1.392629  1.232577
# 126920   78147.0  0.689604 -0.676754 -0.398769  0.577305 -0.269999 -0.634893
# 70909    54071.0  1.146286 -0.358282  0.688945  0.382457 -1.016927 -0.711002
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
y
# Out:
# 112470    0
# 22618     0
# 82232     0
# 126920    0
# 70909     0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2,stratify=y,random_state= 2)

# %%
X_train.shape
# Out:
# (787, 30)

# %%
X_test.shape
# Out:
# (197, 30)

# %%
# Model Training

# %%
model=LogisticRegression()

# %%
# Training the data in lr model with training data
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
# Evaluation 
# Accuracy score

# %%
# Accuracy on training data
xTrainPred=model.predict(X_train)
trainingAcc=accuracy_score(xTrainPred,y_train)

# %%
trainingAcc
# Out:
# 0.9428208386277002

# %%
xTestPred=model.predict(X_test)
testingAcc=accuracy_score(xTestPred,y_test)

# %%
testingAcc
# Out:
# 0.9238578680203046

# %%
cc
